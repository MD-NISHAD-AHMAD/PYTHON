# %% [markdown]
# ## STRING.

# %%
s1 = 'orewa namikaze minato'
s2 = "A child who diesd fighting the wars of the adults"
s3 = """A hero who died protecting 
the village that 
called him a traitor
"""

print(f"string : {s1}\nMemory Location : {id(s1)}\nData Type : {type(s1)}")
# Out:
# string : orewa namikaze minato
# Memory Location : 2331156897568
# Data Type : <class 'str'>
